# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#Calculate the total number of schools
total_schools = len(school_data_complete["school_name"].unique())

# %%
#Calculate the total number of students
total_students = len(school_data_complete["Student ID"].unique())

# %%
#Calculate the total budget
budget_list = school_data_complete["budget"].unique()
total_budget = budget_list.sum()

# %%
#Calculate the average math score
average_math_score = school_data_complete["math_score"].mean()

# %%
#Calculate the average reading score
average_reading_score = school_data_complete["reading_score"].mean()

# %%
#Calculate the percentage of students with a passing math score (70 or greater)
all_math_scores = school_data_complete.loc[(school_data_complete["math_score"] >= 70), ["Student ID","math_score"]]
percentage_passing_math = float(len(all_math_scores)/total_students*100)

# %%
#Calculate the percentage of students with a passing reading score (70 or greater)
all_reading_scores = school_data_complete.loc[(school_data_complete["reading_score"] >= 70), ["Student ID","reading_score"]]
percentage_passing_reading = float(len(all_reading_scores)/total_students*100)

# %%
#Calculate the percentage of students who passed math and reading (% Overall Passing)
overall_scores = school_data_complete.loc[(school_data_complete["math_score"] >= 70) & 
                                          (school_data_complete["reading_score"] >= 70)]
percentage_overall_passing = float(len(overall_scores)/total_students*100)

# %%
#Combine all the attributes together into one Data Frame
district_summary = pd.DataFrame({
    "Total Schools" : [total_schools],
    "Total Students" : [total_students],
    "Total Budget" : [total_budget],
    "Average Math Score" : [average_math_score],
    "Average Reading Score" : [average_reading_score],
    "% Passing Math" : [percentage_passing_math],
    "% Passing Reading" : [percentage_passing_reading],
    "% Overall Passing" : [percentage_overall_passing],
})

# %%
#Format the these two attributes in the Data Frame
district_summary["Total Students"] = district_summary["Total Students"].astype(int).map("{:,}".format)
district_summary["Total Budget"] = district_summary["Total Budget"].astype(float).map("${:,.2f}".format)
district_summary
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
#Summarize the School Type
school_types = pd.DataFrame(school_names["type"].first())
school_types = school_types.rename(columns = {"type" : "School Type"})

# %%
#Group the data by their school names and calculate the total Students based on each school
school_names = school_data_complete.groupby("school_name")
total_students = pd.DataFrame(school_names["Student ID"].count())
total_students = total_students.rename(columns = {"Student ID" : "Total Students"})

# %%
#Calculate the total budget for each school
total_school_budget = pd.DataFrame(school_names["budget"].mean())

# %%
school_size = pd.DataFrame(school_names["size"].mean())
per_student_budget = pd.DataFrame(total_school_budget["budget"]/school_size["size"])
per_student_budget[0] = per_student_budget[0].astype(float).map("${:,.2f}".format)
per_student_budget = per_student_budget.rename(columns = {0 : "Per Student Budget"})

# %%
total_school_budget["budget"] = total_school_budget["budget"].astype(float).map("${:,.2f}".format)
total_school_budget = total_school_budget.rename(columns = {"budget" : "Total School Budget"})

# %%
school_average_math = pd.DataFrame(school_names["math_score"].mean())
school_average_math = school_average_math.rename(columns = {"math_score" : "Average Math Score"})

# %%
school_average_reading = pd.DataFrame(school_names["reading_score"].mean())
school_average_reading = school_average_reading.rename(columns = {"reading_score" : "Average Reading Score"})

# %%
passing_math = pd.DataFrame(school_names["math_score"].agg(lambda x: (x >= 70).sum()))
school_passing_math = pd.DataFrame(passing_math["math_score"] / total_students["Total Students"] * 100)
school_passing_math = school_passing_math.rename(columns = {0 : "% Passing Math"})

# %%
passing_reading = pd.DataFrame(school_names["reading_score"].agg(lambda x: (x >= 70).sum()))
school_passing_reading = pd.DataFrame(passing_reading["reading_score"] / total_students["Total Students"] * 100)
school_passing_reading = school_passing_reading.rename(columns = {0 : "% Passing Reading"})

# %%
overall_passing = pd.DataFrame(school_names.apply(lambda x: ((x["math_score"] >= 70) & (x["reading_score"] >= 70)).sum()))
school_overall_passing = pd.DataFrame(overall_passing[0] / total_students["Total Students"] * 100)
school_overall_passing = school_overall_passing.rename(columns = {0 : "% Overall Passing"})

# %%
school_summary = pd.merge(school_types,total_students, on = "school_name", how = "outer")
school_summary = pd.merge(school_summary,total_school_budget, on = "school_name", how = "outer")
school_summary = pd.merge(school_summary,per_student_budget, on = "school_name", how = "outer")
school_summary = pd.merge(school_summary,school_average_math, on = "school_name", how = "outer")
school_summary = pd.merge(school_summary,school_average_reading, on = "school_name", how = "outer")
school_summary = pd.merge(school_summary,school_passing_math, on = "school_name", how = "outer")
school_summary = pd.merge(school_summary,school_passing_reading, on = "school_name", how = "outer")
school_summary = pd.merge(school_summary,school_overall_passing, on = "school_name", how = "outer")

# %%
school_summary.index.name = None
school_summary
# Out:
#                       School Type  Total Students Total School Budget  \
# Bailey High School       District            4976       $3,124,928.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Figueroa High School     District            2949       $1,884,411.00
# Ford High School         District            2739       $1,763,916.00
# Griffin High School       Charter            1468         $917,500.00
# Hernandez High School    District            4635       $3,022,020.00
# Holden High School        Charter             427         $248,087.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Pena High School          Charter             962         $585,858.00
# Rodriguez High School    District            3999       $2,547,363.00
# Shelton High School       Charter            1761       $1,056,600.00
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
top_performing_schools = school_summary.sort_values(["% Overall Passing"], ascending = False, inplace = False)
top_performing_schools.head(5)
# Out:
#                     School Type  Total Students Total School Budget  \
# school_name
# Cabrera High School     Charter            1858       $1,081,356.00
# Thomas High School      Charter            1635       $1,043,130.00
# Griffin High School     Charter            1468         $917,500.00
# Wilson High School      Charter            2283       $1,319,574.00
# Pena High School        Charter             962         $585,858.00
#
#                     Per Student Budget  Average Math Score  \
# school_name
# Cabrera High School            $582.00           83.061895
# Thomas High School             $638.00           83.418349
# Griffin High School            $625.00           83.351499
# Wilson High School             $578.00           83.274201
# Pena High School               $609.00           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# school_name
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
bottom_performing_schools = school_summary.sort_values(["% Overall Passing"], ascending = True, inplace = False)
bottom_performing_schools.head(5)
# Out:
#                       School Type  Total Students Total School Budget  \
# school_name
# Rodriguez High School    District            3999       $2,547,363.00
# Figueroa High School     District            2949       $1,884,411.00
# Huang High School        District            2917       $1,910,635.00
# Hernandez High School    District            4635       $3,022,020.00
# Johnson High School      District            4761       $3,094,650.00
#
#                       Per Student Budget  Average Math Score  \
# school_name
# Rodriguez High School            $637.00           76.842711
# Figueroa High School             $639.00           76.711767
# Huang High School                $655.00           76.629414
# Hernandez High School            $652.00           77.289752
# Johnson High School              $650.00           77.072464
#
#                        Average Reading Score  % Passing Math  \
# school_name
# Rodriguez High School              80.744686       66.366592
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
ninth_grade = school_data_complete[(school_data_complete["grade"] == "9th")]
tenth_grade = school_data_complete[(school_data_complete["grade"] == "10th")]
eleventh_grade = school_data_complete[(school_data_complete["grade"] == "11th")]
twelveth_grade = school_data_complete[(school_data_complete["grade"] == "12th")]

# %%
average_math_score_9th = pd.DataFrame(ninth_grade.groupby("school_name")["math_score"].mean())
average_math_score_9th = average_math_score_9th.rename(columns = {"math_score":"9th"})

# %%
average_math_score_10th = pd.DataFrame(tenth_grade.groupby("school_name")["math_score"].mean())
average_math_score_10th = average_math_score_10th.rename(columns = {"math_score":"10th"})

# %%
average_math_score_11th = pd.DataFrame(eleventh_grade.groupby("school_name")["math_score"].mean())
average_math_score_11th = average_math_score_11th.rename(columns = {"math_score":"11th"})

# %%
average_math_score_12th = pd.DataFrame(twelveth_grade.groupby("school_name")["math_score"].mean())
average_math_score_12th = average_math_score_12th.rename(columns = {"math_score":"12th"})

# %%
math_score_by_grade = pd.merge(average_math_score_9th,average_math_score_10th,on="school_name",how = "outer")
math_score_by_grade = pd.merge(math_score_by_grade,average_math_score_11th,on="school_name",how = "outer")
math_score_by_grade = pd.merge(math_score_by_grade,average_math_score_12th,on="school_name",how = "outer")

# %%
math_score_by_grade.index.name = None
math_score_by_grade
# Out:
#                              9th       10th       11th       12th
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
average_reading_score_9th = pd.DataFrame(ninth_grade.groupby("school_name")["reading_score"].mean())
average_reading_score_9th = average_reading_score_9th.rename(columns = {"reading_score":"9th"})

# %%
average_reading_score_10th = pd.DataFrame(tenth_grade.groupby("school_name")["reading_score"].mean())
average_reading_score_10th = average_reading_score_10th.rename(columns = {"reading_score":"10th"})

# %%
average_reading_score_11th = pd.DataFrame(eleventh_grade.groupby("school_name")["reading_score"].mean())
average_reading_score_11th = average_reading_score_11th.rename(columns = {"reading_score":"11th"})

# %%
average_reading_score_12th = pd.DataFrame(twelveth_grade.groupby("school_name")["reading_score"].mean())
average_reading_score_12th = average_reading_score_12th.rename(columns = {"reading_score":"12th"})

# %%
reading_score_by_grade = pd.merge(average_reading_score_9th,average_reading_score_10th,on="school_name",how = "outer")
reading_score_by_grade = pd.merge(reading_score_by_grade,average_reading_score_11th,on="school_name",how = "outer")
reading_score_by_grade = pd.merge(reading_score_by_grade,average_reading_score_12th,on="school_name",how = "outer")

# %%
reading_score_by_grade.index.name = None
reading_score_by_grade
# Out:
#                              9th       10th       11th       12th
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
school_spending_data = school_data_complete
school_spending_data["Per Student Budget"] = school_spending_data["budget"]/school_spending_data["size"]

# %%
spending_bins = [0,584.99,629.99,644.99,675.99]
spending_group_names = ["<$584","$585-629","$630-644","$645-675"]
school_spending_data["Spending Ranges (Per Student)"] = pd.cut(school_spending_data["Per Student Budget"],
                                                               bins = spending_bins,
                                                               labels = spending_group_names)

# %%
spending_ranges = school_spending_data.groupby("Spending Ranges (Per Student)")
spending_average_math = pd.DataFrame(spending_ranges["math_score"].mean())
spending_average_math = spending_average_math.rename(columns = {"math_score" : "Average Math Score"})
spending_average_math["Average Math Score"] = spending_average_math["Average Math Score"].astype(float).map("{:.2f}".format)

# %%
spending_average_reading = pd.DataFrame(spending_ranges["reading_score"].mean())
spending_average_reading["reading_score"] = spending_average_reading["reading_score"].astype(float).map("{:.2f}".format)
spending_average_reading = spending_average_reading.rename(columns = {"reading_score" : "Average Reading Score"})

# %%
spending_math_pass = pd.DataFrame(spending_ranges["math_score"].agg(lambda x: (x >= 70).sum()))
spending_passing_math = pd.DataFrame(spending_math_pass["math_score"] / spending_ranges["Student ID"].count() * 100)
spending_passing_math = spending_passing_math.rename(columns = {0 : "% Passing Math"})
spending_passing_math["% Passing Math"] = spending_passing_math["% Passing Math"].astype(float).map("{:.2f}".format)

# %%
spending_reading_pass = pd.DataFrame(spending_ranges["reading_score"].agg(lambda x: (x >= 70).sum()))
spending_passing_reading = pd.DataFrame(spending_reading_pass["reading_score"] / spending_ranges["Student ID"].count() * 100)
spending_passing_reading = spending_passing_reading.rename(columns = {0 : "% Passing Reading"})
spending_passing_reading["% Passing Reading"] = spending_passing_reading["% Passing Reading"].astype(float).map("{:.2f}".format)

# %%
spending_overall_passing = pd.DataFrame(
    spending_ranges.apply(lambda x:((x["math_score"] >= 70) & (x["reading_score"] >= 70)).sum()))
spending_overall_passing = pd.DataFrame(spending_overall_pass[0] / spending_ranges["Student ID"].count() * 100)
spending_overall_passing = spending_overall_passing.rename(columns = {0 : "% Overall Passing"})
spending_overall_passing["% Overall Passing"] = spending_overall_passing["% Overall Passing"].astype(float).map("{:.2f}".format)

# %%
school_spending = pd.merge(spending_average_math,spending_average_reading, on = "Spending Ranges (Per Student)", how = "outer")
school_spending = pd.merge(school_spending, spending_passing_math, on = "Spending Ranges (Per Student)", how = "outer")
school_spending = pd.merge(school_spending, spending_passing_reading, on = "Spending Ranges (Per Student)", how = "outer")
school_spending = pd.merge(school_spending, spending_overall_passing, on = "Spending Ranges (Per Student)", how = "outer")
school_spending
# Out:
#                               Average Math Score Average Reading Score  \
# Spending Ranges (Per Student)
# <$584                                      83.36                 83.96
# $585-629                                   79.98                 82.31
# $630-644                                   77.82                 81.30
# $645-675                                   77.05                 81.01
#
#                               % Passing Math % Passing Reading  \
# Spending Ranges (Per Student)
# <$584                                  93.70             96.69
# $585-629                               79.11             88.51
# $630-644                               70.62             82.60
# $645-675                               66.23             81.11
#
#                               % Overall Passing
# Spending Ranges (Per Student)
# <$584                                     90.64
# $585-629                                  70.94
# $630-644                                  58.84
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
school_size_data = school_data_complete

# %%
size_bins = [0,999.99,1999.99,4999.99]
size_group_names = ["Small (<1000)","Medium (1000-2000)","Large (2000-5000)"]
school_size_data["School Size"] = pd.cut(school_size_data["size"],bins = size_bins, labels = size_group_names)

# %%
school_size = school_size_data.groupby("School Size")
size_average_math = pd.DataFrame(school_size["math_score"].mean())
size_average_math = size_average_math.rename(columns = {"math_score" : "Average Math Score"})

# %%
size_average_reading = pd.DataFrame(school_size["reading_score"].mean())
size_average_reading = size_average_reading.rename(columns = {"reading_score" : "Average Reading Score"})

# %%
size_math_pass = pd.DataFrame(school_size["math_score"].agg(lambda x: (x >= 70).sum()))
size_passing_math = pd.DataFrame(size_math_pass["math_score"] / (school_size["Student ID"].count()) * 100)
size_passing_math = size_passing_math.rename(columns = {0 : "% Passing Math"})

# %%
size_reading_pass = pd.DataFrame(school_size["reading_score"].agg(lambda x: (x >= 70).sum()))
size_passing_reading = pd.DataFrame(size_reading_pass["reading_score"] / (school_size["Student ID"].count()) * 100)
size_passing_reading = size_passing_reading.rename(columns = {0 : "% Passing Reading"})

# %%
size_overall_pass = pd.DataFrame(school_size.apply(lambda x: ((x["math_score"] >= 70) & (x["reading_score"] >= 70)).sum()))
size_overall_passing = pd.DataFrame(size_overall_pass[0] / (school_size["Student ID"].count()) * 100)
size_overall_passing = size_overall_passing.rename(columns = {0 : "% Overall Passing"})

# %%
school_size_final = pd.merge(size_average_math,size_average_reading, on = "School Size", how = "outer")
school_size_final = pd.merge(school_size_final, size_passing_math, on = "School Size", how = "outer")
school_size_final = pd.merge(school_size_final, size_passing_reading, on = "School Size", how = "outer")
school_size_final = pd.merge(school_size_final, size_overall_passing, on = "School Size", how = "outer")
school_size_final
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.828654              83.974082       93.952484
# Medium (1000-2000)           83.372682              83.867989       93.616522
# Large (2000-5000)            77.477597              81.198674       68.652380
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1000)               96.040317          90.136789
# Medium (1000-2000)          96.773058          90.624267
# Large (2000-5000)           82.125158          56.574046

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
school_type_data = school_data_complete
school_type_data = school_type_data.rename(columns = {"type" : "School Type"})

# %%
school_type = school_type_data.groupby("School Type")
type_average_math = pd.DataFrame(school_type["math_score"].mean())
type_average_math = type_average_math.rename(columns = {"math_score" : "Average Math Score"})

# %%
type_average_reading = pd.DataFrame(school_type["reading_score"].mean())
type_average_reading = type_average_reading.rename(columns = {"reading_score" : "Average Reading Score"})

# %%
type_math_pass = pd.DataFrame(school_type["math_score"].agg(lambda x: (x >= 70).sum()))
type_passing_math = pd.DataFrame(type_math_pass["math_score"] / (school_type["Student ID"].count()) * 100)
type_passing_math = type_passing_math.rename(columns = {0 : "% Passing Math"})

# %%
type_reading_pass = pd.DataFrame(school_type["reading_score"].agg(lambda x: (x >= 70).sum()))
type_passing_reading = pd.DataFrame(type_reading_pass["reading_score"] / (school_type["Student ID"].count()) * 100)
type_passing_reading = type_passing_reading.rename(columns = {0 : "% Passing Reading"})

# %%
type_overall_pass = pd.DataFrame(school_type.apply(lambda x: ((x["math_score"] >= 70) & (x["reading_score"] >= 70)).sum()))
type_overall_passing = pd.DataFrame(type_overall_pass[0] / (school_type["Student ID"].count()) * 100)
type_overall_passing = type_overall_passing.rename(columns = {0 : "% Overall Passing"})

# %%
school_type_final = pd.merge(type_average_math,type_average_reading, on = "School Type", how = "outer")
school_type_final = pd.merge(school_type_final, type_passing_math, on = "School Type", how = "outer")
school_type_final = pd.merge(school_type_final, type_passing_reading, on = "School Type", how = "outer")
school_type_final = pd.merge(school_type_final, type_overall_passing, on = "School Type", how = "outer")
school_type_final
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.406183              83.902821       93.701821
# District              76.987026              80.962485       66.518387
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.645891          90.560932
# District             80.905249          53.695878
