# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as sts

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Initialize sempty lists for the for loop and use to creating DataFrame later
city_names = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# %%
# Build query URL and request results in Celsius. Populate the corresponding lists for the building of the dataframe
record = 1
set_number = 1
print("Beginning Data Retrieval")
print("-----------------------------")
for city in cities:
    query = city
    units = "imperial"
    # Retrieve the weather data from the URL
    base_url = "http://api.openweathermap.org/data/2.5/weather?"
    parameters = f"appid={api_key}&q={query}&units={units}"
    url = base_url + parameters 
    response = requests.get(url).json()
    if response["cod"] != 200: # If the response is not 200, skip the current data entry
        print("City not found. Skipping...")
        pass
    else: # Otherwise, append the empty lists with their corresponding data attributes
        city_names.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        print(f"Processing Record {record} of Set {set_number} | {city}")
        record += 1
        if record == 50:
            time.sleep(3)
            record = 1
            set_number += 1
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | victoria
# Processing Record 2 of Set 1 | nome
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | phonhong
# Processing Record 6 of Set 1 | taltal
# Processing Record 7 of Set 1 | nyrob
# Processing Record 8 of Set 1 | ostrovnoy
# Processing Record 9 of Set 1 | omboue
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | yar-sale
# Processing Record 14 of Set 1 | sonepur
# Processing Record 15 of Set 1 | concepcion del oro
# Processing Record 16 of Set 1 | mar del plata
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | saint george
# Processing Record 19 of Set 1 | araouane
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | birjand
# Processing Record 23 of Set 1 | cabo san lucas
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | carnarvon
# Processing Record 26 of Set 1 | iqaluit
# Processing Record 27 of Set 1 | cap malheureux
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | havoysund
# Processing Record 30 of Set 1 | saskylakh
# Processing Record 31 of Set 1 | fairbanks
# City not found. Skipping...
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | bredasdorp
# City not found. Skipping...
# Processing Record 34 of Set 1 | katsuura
# Processing Record 35 of Set 1 | buribay
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | arys
# Processing Record 38 of Set 1 | tabou
# Processing Record 39 of Set 1 | verkhnyaya inta
# Processing Record 40 of Set 1 | popondetta
# Processing Record 41 of Set 1 | geraldton
# Processing Record 42 of Set 1 | lompoc
# City not found. Skipping...
# Processing Record 43 of Set 1 | uppsala
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | vao
# Processing Record 46 of Set 1 | san jose
# Processing Record 47 of Set 1 | chokurdakh
# Processing Record 48 of Set 1 | bundaberg
# Processing Record 49 of Set 1 | lakes entrance
# Processing Record 1 of Set 2 | baracoa
# Processing Record 2 of Set 2 | tasiilaq
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | te anau
# Processing Record 5 of Set 2 | aklavik
# Processing Record 6 of Set 2 | la rioja
# Processing Record 7 of Set 2 | nanortalik
# Processing Record 8 of Set 2 | sao joao da barra
# Processing Record 9 of Set 2 | eureka
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | semey
# Processing Record 12 of Set 2 | san pedro
# Processing Record 13 of Set 2 | beringovskiy
# Processing Record 14 of Set 2 | pavlovka
# Processing Record 15 of Set 2 | vanimo
# Processing Record 16 of Set 2 | eyl
# Processing Record 17 of Set 2 | flinders
# Processing Record 18 of Set 2 | leopoldina
# Processing Record 19 of Set 2 | ocean springs
# Processing Record 20 of Set 2 | faanui
# Processing Record 21 of Set 2 | lata
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | albany
# Processing Record 25 of Set 2 | berlevag
# Processing Record 26 of Set 2 | kaitangata
# Processing Record 27 of Set 2 | bambous virieux
# Processing Record 28 of Set 2 | mahebourg
# Processing Record 29 of Set 2 | igrim
# Processing Record 30 of Set 2 | airai
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 31 of Set 2 | west wendover
# City not found. Skipping...
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | bridlington
# Processing Record 34 of Set 2 | krasnoselkup
# Processing Record 35 of Set 2 | constitucion
# Processing Record 36 of Set 2 | caravelas
# Processing Record 37 of Set 2 | mount gambier
# Processing Record 38 of Set 2 | cherskiy
# Processing Record 39 of Set 2 | haverfordwest
# Processing Record 40 of Set 2 | provideniya
# Processing Record 41 of Set 2 | castro
# Processing Record 42 of Set 2 | quatre cocos
# Processing Record 43 of Set 2 | solnechnyy
# Processing Record 44 of Set 2 | rio grande
# Processing Record 45 of Set 2 | tual
# City not found. Skipping...
# Processing Record 46 of Set 2 | dashitou
# Processing Record 47 of Set 2 | isla vista
# Processing Record 48 of Set 2 | kapaa
# Processing Record 49 of Set 2 | crestview
# Processing Record 1 of Set 3 | korla
# Processing Record 2 of Set 3 | saint-philippe
# Processing Record 3 of Set 3 | cockburn town
# Processing Record 4 of Set 3 | jinchang
# Processing Record 5 of Set 3 | klaksvik
# Processing Record 6 of Set 3 | guerrero negro
# Processing Record 7 of Set 3 | portales
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | manokwari
# Processing Record 10 of Set 3 | rewa
# Processing Record 11 of Set 3 | bud
# Processing Record 12 of Set 3 | kibaya
# Processing Record 13 of Set 3 | toamasina
# Processing Record 14 of Set 3 | port elizabeth
# Processing Record 15 of Set 3 | sistranda
# Processing Record 16 of Set 3 | torbay
# Processing Record 17 of Set 3 | coihaique
# Processing Record 18 of Set 3 | anadyr
# Processing Record 19 of Set 3 | grand gaube
# Processing Record 20 of Set 3 | atambua
# Processing Record 21 of Set 3 | arrecife
# Processing Record 22 of Set 3 | nikolayevsk-na-amure
# Processing Record 23 of Set 3 | isangel
# Processing Record 24 of Set 3 | solvychegodsk
# Processing Record 25 of Set 3 | cape town
# City not found. Skipping...
# Processing Record 26 of Set 3 | houma
# City not found. Skipping...
# Processing Record 27 of Set 3 | barrow
# City not found. Skipping...
# Processing Record 28 of Set 3 | sadon
# Processing Record 29 of Set 3 | kandri
# Processing Record 30 of Set 3 | saquena
# Processing Record 31 of Set 3 | jieshi
# Processing Record 32 of Set 3 | si sa ket
# Processing Record 33 of Set 3 | lagoa
# Processing Record 34 of Set 3 | kodiak
# Processing Record 35 of Set 3 | tuatapere
# Processing Record 36 of Set 3 | owando
# Processing Record 37 of Set 3 | pangnirtung
# Processing Record 38 of Set 3 | zaysan
# Processing Record 39 of Set 3 | vaini
# Processing Record 40 of Set 3 | hobyo
# Processing Record 41 of Set 3 | port lincoln
# Processing Record 42 of Set 3 | codrington
# Processing Record 43 of Set 3 | ussel
# Processing Record 44 of Set 3 | kamenka
# Processing Record 45 of Set 3 | bontang
# Processing Record 46 of Set 3 | morro bay
# Processing Record 47 of Set 3 | bardiyah
# Processing Record 48 of Set 3 | hermanus
# Processing Record 49 of Set 3 | puerto ayora
# Processing Record 1 of Set 4 | novosokolniki
# Processing Record 2 of Set 4 | peno
# Processing Record 3 of Set 4 | yulara
# Processing Record 4 of Set 4 | tselinnoye
# Processing Record 5 of Set 4 | mangan
# Processing Record 6 of Set 4 | saldanha
# Processing Record 7 of Set 4 | santona
# Processing Record 8 of Set 4 | san quintin
# Processing Record 9 of Set 4 | kieta
# Processing Record 10 of Set 4 | tailai
# Processing Record 11 of Set 4 | nargana
# Processing Record 12 of Set 4 | katangli
# Processing Record 13 of Set 4 | moundou
# Processing Record 14 of Set 4 | mweka
# City not found. Skipping...
# Processing Record 15 of Set 4 | sung noen
# Processing Record 16 of Set 4 | upernavik
# City not found. Skipping...
# Processing Record 17 of Set 4 | shanhetun
# Processing Record 18 of Set 4 | albion
# Processing Record 19 of Set 4 | kochi
# Processing Record 20 of Set 4 | hithadhoo
# Processing Record 21 of Set 4 | bengkulu
# Processing Record 22 of Set 4 | lebu
# Processing Record 23 of Set 4 | sambava
# Processing Record 24 of Set 4 | husavik
# Processing Record 25 of Set 4 | chancay
# Processing Record 26 of Set 4 | sompeta
# City not found. Skipping...
# Processing Record 27 of Set 4 | antsohihy
# Processing Record 28 of Set 4 | kahului
# Processing Record 29 of Set 4 | prince rupert
# Processing Record 30 of Set 4 | pisco
# Processing Record 31 of Set 4 | chake chake
# Processing Record 32 of Set 4 | chernukha
# Processing Record 33 of Set 4 | dovbysh
# Processing Record 34 of Set 4 | kashary
# Processing Record 35 of Set 4 | shimoda
# Processing Record 36 of Set 4 | srednekolymsk
# Processing Record 37 of Set 4 | luganville
# Processing Record 38 of Set 4 | miri
# Processing Record 39 of Set 4 | ponta do sol
# Processing Record 40 of Set 4 | lodja
# Processing Record 41 of Set 4 | norman wells
# Processing Record 42 of Set 4 | clyde river
# Processing Record 43 of Set 4 | touros
# Processing Record 44 of Set 4 | tungor
# Processing Record 45 of Set 4 | pedasi
# Processing Record 46 of Set 4 | bethel
# Processing Record 47 of Set 4 | tenkodogo
# Processing Record 48 of Set 4 | marsa matruh
# Processing Record 49 of Set 4 | portland
# City not found. Skipping...
# Processing Record 1 of Set 5 | kirakira
# Processing Record 2 of Set 5 | cabedelo
# Processing Record 3 of Set 5 | leningradskiy
# Processing Record 4 of Set 5 | silopi
# Processing Record 5 of Set 5 | moron
# Processing Record 6 of Set 5 | evensk
# Processing Record 7 of Set 5 | inirida
# Processing Record 8 of Set 5 | hasaki
# Processing Record 9 of Set 5 | vestmannaeyjar
# Processing Record 10 of Set 5 | haines junction
# Processing Record 11 of Set 5 | abu samrah
# Processing Record 12 of Set 5 | saint-pierre
# Processing Record 13 of Set 5 | ciudad bolivar
# Processing Record 14 of Set 5 | sabzevar
# Processing Record 15 of Set 5 | port keats
# Processing Record 16 of Set 5 | kimbe
# Processing Record 17 of Set 5 | dancheng
# Processing Record 18 of Set 5 | itajuba
# Processing Record 19 of Set 5 | sorland
# Processing Record 20 of Set 5 | killybegs
# Processing Record 21 of Set 5 | san buenaventura
# Processing Record 22 of Set 5 | aksu
# Processing Record 23 of Set 5 | churapcha
# Processing Record 24 of Set 5 | barcelos
# Processing Record 25 of Set 5 | xingtai
# Processing Record 26 of Set 5 | meulaboh
# Processing Record 27 of Set 5 | boa vista
# Processing Record 28 of Set 5 | neiafu
# Processing Record 29 of Set 5 | puerto escondido
# City not found. Skipping...
# Processing Record 30 of Set 5 | alofi
# Processing Record 31 of Set 5 | zhezkazgan
# Processing Record 32 of Set 5 | ovsyanka
# Processing Record 33 of Set 5 | raudeberg
# Processing Record 34 of Set 5 | wahiawa
# Processing Record 35 of Set 5 | matara
# Processing Record 36 of Set 5 | noyabrsk
# Processing Record 37 of Set 5 | marystown
# Processing Record 38 of Set 5 | ponta delgada
# Processing Record 39 of Set 5 | nikolskoye
# Processing Record 40 of Set 5 | dharchula
# Processing Record 41 of Set 5 | puyang
# City not found. Skipping...
# Processing Record 42 of Set 5 | longyearbyen
# City not found. Skipping...
# Processing Record 43 of Set 5 | bongandanga
# Processing Record 44 of Set 5 | tuktoyaktuk
# Processing Record 45 of Set 5 | anaco
# Processing Record 46 of Set 5 | pak phanang
# Processing Record 47 of Set 5 | genhe
# Processing Record 48 of Set 5 | knysna
# Processing Record 49 of Set 5 | sitka
# Processing Record 1 of Set 6 | oktyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 6 | grindavik
# Processing Record 3 of Set 6 | quelimane
# Processing Record 4 of Set 6 | fortuna
# Processing Record 5 of Set 6 | boromlya
# City not found. Skipping...
# Processing Record 6 of Set 6 | tura
# Processing Record 7 of Set 6 | sumy
# City not found. Skipping...
# Processing Record 8 of Set 6 | kavaratti
# Processing Record 9 of Set 6 | beya
# Processing Record 10 of Set 6 | quzhou
# Processing Record 11 of Set 6 | canutama
# Processing Record 12 of Set 6 | ribeira grande
# Processing Record 13 of Set 6 | gloggnitz
# Processing Record 14 of Set 6 | sorkjosen
# Processing Record 15 of Set 6 | nhulunbuy
# Processing Record 16 of Set 6 | oriximina
# Processing Record 17 of Set 6 | fort nelson
# Processing Record 18 of Set 6 | dunedin
# Processing Record 19 of Set 6 | rong kwang
# Processing Record 20 of Set 6 | nizhniy kuranakh
# Processing Record 21 of Set 6 | bac lieu
# Processing Record 22 of Set 6 | richards bay
# Processing Record 23 of Set 6 | sao miguel do araguaia
# Processing Record 24 of Set 6 | asau
# Processing Record 25 of Set 6 | mirzapur
# Processing Record 26 of Set 6 | jiuquan
# Processing Record 27 of Set 6 | rodez
# Processing Record 28 of Set 6 | yarmouth
# Processing Record 29 of Set 6 | nova russas
# City not found. Skipping...
# Processing Record 30 of Set 6 | alyangula
# Processing Record 31 of Set 6 | talnakh
# Processing Record 32 of Set 6 | zhigansk
# Processing Record 33 of Set 6 | tansen
# Processing Record 34 of Set 6 | kachiry
# Processing Record 35 of Set 6 | okha
# Processing Record 36 of Set 6 | bandar-e anzali
# Processing Record 37 of Set 6 | rorvik
# Processing Record 38 of Set 6 | luwuk
# City not found. Skipping...
# Processing Record 39 of Set 6 | ormara
# Processing Record 40 of Set 6 | muros
# Processing Record 41 of Set 6 | college
# Processing Record 42 of Set 6 | derzhavinsk
# Processing Record 43 of Set 6 | chingirlau
# Processing Record 44 of Set 6 | kutum
# Processing Record 45 of Set 6 | ahipara
# Processing Record 46 of Set 6 | yilan
# Processing Record 47 of Set 6 | bubaque
# Processing Record 48 of Set 6 | lubango
# Processing Record 49 of Set 6 | inhambane
# City not found. Skipping...
# Processing Record 1 of Set 7 | nantucket
# Processing Record 2 of Set 7 | arraial do cabo
# Processing Record 3 of Set 7 | qandala
# Processing Record 4 of Set 7 | thinadhoo
# Processing Record 5 of Set 7 | san vicente
# City not found. Skipping...
# Processing Record 6 of Set 7 | broken hill
# Processing Record 7 of Set 7 | coxim
# Processing Record 8 of Set 7 | belyy yar
# Processing Record 9 of Set 7 | sao filipe
# City not found. Skipping...
# Processing Record 10 of Set 7 | byron bay
# Processing Record 11 of Set 7 | mahenge
# Processing Record 12 of Set 7 | belomorsk
# Processing Record 13 of Set 7 | pandan
# Processing Record 14 of Set 7 | dikson
# Processing Record 15 of Set 7 | acapulco
# Processing Record 16 of Set 7 | thompson
# Processing Record 17 of Set 7 | paamiut
# Processing Record 18 of Set 7 | mapastepec
# Processing Record 19 of Set 7 | manicore
# Processing Record 20 of Set 7 | roald
# Processing Record 21 of Set 7 | port blair
# Processing Record 22 of Set 7 | harper
# Processing Record 23 of Set 7 | natchitoches
# Processing Record 24 of Set 7 | bar harbor
# Processing Record 25 of Set 7 | ilulissat
# Processing Record 26 of Set 7 | alexandria
# Processing Record 27 of Set 7 | brae
# Processing Record 28 of Set 7 | vardo
# City not found. Skipping...
# Processing Record 29 of Set 7 | xingyi
# Processing Record 30 of Set 7 | severo-kurilsk
# Processing Record 31 of Set 7 | ust-nera
# City not found. Skipping...
# Processing Record 32 of Set 7 | catalao
# Processing Record 33 of Set 7 | kasongo-lunda
# Processing Record 34 of Set 7 | metro
# Processing Record 35 of Set 7 | slavsk
# Processing Record 36 of Set 7 | adre
# City not found. Skipping...
# Processing Record 37 of Set 7 | salinopolis
# Processing Record 38 of Set 7 | dondo
# Processing Record 39 of Set 7 | nuuk
# Processing Record 40 of Set 7 | kununurra
# Processing Record 41 of Set 7 | wanning
# Processing Record 42 of Set 7 | kungurtug
# Processing Record 43 of Set 7 | tynda
# City not found. Skipping...
# Processing Record 44 of Set 7 | hermosillo
# Processing Record 45 of Set 7 | adrar
# Processing Record 46 of Set 7 | marienburg
# Processing Record 47 of Set 7 | boguchany
# Processing Record 48 of Set 7 | la tuque
# Processing Record 49 of Set 7 | maragogi
# Processing Record 1 of Set 8 | lardos
# Processing Record 2 of Set 8 | manbij
# Processing Record 3 of Set 8 | pochutla
# Processing Record 4 of Set 8 | trairi
# Processing Record 5 of Set 8 | ornskoldsvik
# Processing Record 6 of Set 8 | akdepe
# Processing Record 7 of Set 8 | sept-iles
# Processing Record 8 of Set 8 | mocuba
# Processing Record 9 of Set 8 | makakilo city
# Processing Record 10 of Set 8 | otane
# City not found. Skipping...
# Processing Record 11 of Set 8 | lerwick
# Processing Record 12 of Set 8 | kumluca
# Processing Record 13 of Set 8 | taoudenni
# Processing Record 14 of Set 8 | kavieng
# Processing Record 15 of Set 8 | san patricio
# Processing Record 16 of Set 8 | sur
# Processing Record 17 of Set 8 | hope
# Processing Record 18 of Set 8 | waingapu
# Processing Record 19 of Set 8 | hovd
# Processing Record 20 of Set 8 | niesky
# Processing Record 21 of Set 8 | galle
# Processing Record 22 of Set 8 | whitehorse
# Processing Record 23 of Set 8 | mahbubnagar
# Processing Record 24 of Set 8 | berbera
# Processing Record 25 of Set 8 | andros town
# Processing Record 26 of Set 8 | serpa
# Processing Record 27 of Set 8 | lorengau
# Processing Record 28 of Set 8 | kaohsiung
# Processing Record 29 of Set 8 | tunceli
# Processing Record 30 of Set 8 | bathsheba
# Processing Record 31 of Set 8 | saint-georges
# Processing Record 32 of Set 8 | namibe
# Processing Record 33 of Set 8 | bilibino
# Processing Record 34 of Set 8 | tommot
# Processing Record 35 of Set 8 | boo
# Processing Record 36 of Set 8 | souillac
# Processing Record 37 of Set 8 | mount isa
# Processing Record 38 of Set 8 | kruisfontein
# Processing Record 39 of Set 8 | kaliua
# Processing Record 40 of Set 8 | viedma
# Processing Record 41 of Set 8 | kedrovyy
# Processing Record 42 of Set 8 | acarau
# Processing Record 43 of Set 8 | pevek
# City not found. Skipping...
# Processing Record 44 of Set 8 | dingle
# Processing Record 45 of Set 8 | carutapera
# Processing Record 46 of Set 8 | san cristobal
# Processing Record 47 of Set 8 | santiago
# Processing Record 48 of Set 8 | batticaloa
# Processing Record 49 of Set 8 | rybachiy
# Processing Record 1 of Set 9 | mahajanga
# Processing Record 2 of Set 9 | milkovo
# Processing Record 3 of Set 9 | olafsvik
# Processing Record 4 of Set 9 | verkhoyansk
# Processing Record 5 of Set 9 | itaqui
# City not found. Skipping...
# Processing Record 6 of Set 9 | pearland
# Processing Record 7 of Set 9 | santa maria
# Processing Record 8 of Set 9 | samarai
# Processing Record 9 of Set 9 | laguna
# Processing Record 10 of Set 9 | palana
# Processing Record 11 of Set 9 | ejura
# Processing Record 12 of Set 9 | chuy
# Processing Record 13 of Set 9 | novodolinskiy
# Processing Record 14 of Set 9 | jacareacanga
# Processing Record 15 of Set 9 | dongli
# Processing Record 16 of Set 9 | chupa
# Processing Record 17 of Set 9 | severobaykalsk
# Processing Record 18 of Set 9 | jutai
# Processing Record 19 of Set 9 | furano
# Processing Record 20 of Set 9 | mount pleasant
# Processing Record 21 of Set 9 | fukue
# Processing Record 22 of Set 9 | ancud
# Processing Record 23 of Set 9 | mercedes
# Processing Record 24 of Set 9 | sao joao do paraiso
# Processing Record 25 of Set 9 | khatanga
# Processing Record 26 of Set 9 | komsomolskiy
# Processing Record 27 of Set 9 | gonbad-e qabus
# Processing Record 28 of Set 9 | kindu
# Processing Record 29 of Set 9 | raga
# Processing Record 30 of Set 9 | altay
# City not found. Skipping...
# Processing Record 31 of Set 9 | satipo
# Processing Record 32 of Set 9 | ocos
# Processing Record 33 of Set 9 | honningsvag
# Processing Record 34 of Set 9 | emba
# Processing Record 35 of Set 9 | nova zagora
# Processing Record 36 of Set 9 | banjar
# Processing Record 37 of Set 9 | pacific grove
# Processing Record 38 of Set 9 | fare
# Processing Record 39 of Set 9 | bara
# Processing Record 40 of Set 9 | kokopo
# Processing Record 41 of Set 9 | ngerengere
# Processing Record 42 of Set 9 | mehamn
# Processing Record 43 of Set 9 | cayenne
# Processing Record 44 of Set 9 | carahue
# Processing Record 45 of Set 9 | kattivakkam
# Processing Record 46 of Set 9 | dickinson
# Processing Record 47 of Set 9 | les cayes
# City not found. Skipping...
# Processing Record 48 of Set 9 | republic
# Processing Record 49 of Set 9 | praia
# Processing Record 1 of Set 10 | capaci
# Processing Record 2 of Set 10 | burnie
# Processing Record 3 of Set 10 | skjervoy
# Processing Record 4 of Set 10 | moroto
# Processing Record 5 of Set 10 | udachnyy
# Processing Record 6 of Set 10 | moussoro
# Processing Record 7 of Set 10 | qaqortoq
# Processing Record 8 of Set 10 | alice springs
# Processing Record 9 of Set 10 | general bravo
# Processing Record 10 of Set 10 | tessalit
# Processing Record 11 of Set 10 | parintins
# Processing Record 12 of Set 10 | northam
# Processing Record 13 of Set 10 | geseke
# Processing Record 14 of Set 10 | qom
# Processing Record 15 of Set 10 | antalaha
# Processing Record 16 of Set 10 | goderich
# Processing Record 17 of Set 10 | namie
# Processing Record 18 of Set 10 | myanaung
# Processing Record 19 of Set 10 | aitape
# Processing Record 20 of Set 10 | gasa
# City not found. Skipping...
# Processing Record 21 of Set 10 | launceston
# City not found. Skipping...
# Processing Record 22 of Set 10 | marana
# Processing Record 23 of Set 10 | cururupu
# Processing Record 24 of Set 10 | port macquarie
# Processing Record 25 of Set 10 | broome
# Processing Record 26 of Set 10 | akhtubinsk
# Processing Record 27 of Set 10 | north bend
# Processing Record 28 of Set 10 | moose factory
# Processing Record 29 of Set 10 | navahrudak
# Processing Record 30 of Set 10 | lasa
# Processing Record 31 of Set 10 | zorlentu mare
# Processing Record 32 of Set 10 | ballina
# Processing Record 33 of Set 10 | iskateley
# Processing Record 34 of Set 10 | uong bi
# Processing Record 35 of Set 10 | baykit
# City not found. Skipping...
# Processing Record 36 of Set 10 | loukhi
# Processing Record 37 of Set 10 | moindou
# Processing Record 38 of Set 10 | saint-augustin
# Processing Record 39 of Set 10 | puerto madero
# Processing Record 40 of Set 10 | magadan
# Processing Record 41 of Set 10 | esperance
# Processing Record 42 of Set 10 | joutseno
# Processing Record 43 of Set 10 | svetlaya
# Processing Record 44 of Set 10 | griffith
# Processing Record 45 of Set 10 | muleba
# Processing Record 46 of Set 10 | sai buri
# Processing Record 47 of Set 10 | makungu
# Processing Record 48 of Set 10 | bereda
# Processing Record 49 of Set 10 | narsaq
# Processing Record 1 of Set 11 | teahupoo
# Processing Record 2 of Set 11 | biak
# Processing Record 3 of Set 11 | jijiga
# Processing Record 4 of Set 11 | campo maior
# City not found. Skipping...
# Processing Record 5 of Set 11 | cascais
# Processing Record 6 of Set 11 | morwell
# Processing Record 7 of Set 11 | yulin
# Processing Record 8 of Set 11 | tautira
# City not found. Skipping...
# Processing Record 9 of Set 11 | namatanai
# Processing Record 10 of Set 11 | russell
# Processing Record 11 of Set 11 | okhotsk
# Processing Record 12 of Set 11 | tabuk
# Processing Record 13 of Set 11 | sinnamary
# Processing Record 14 of Set 11 | bristol
# Processing Record 15 of Set 11 | orlik
# Processing Record 16 of Set 11 | lithgow
# Processing Record 17 of Set 11 | narsingi
# City not found. Skipping...
# Processing Record 18 of Set 11 | benoy
# Processing Record 19 of Set 11 | vagur
# Processing Record 20 of Set 11 | puerto del rosario
# Processing Record 21 of Set 11 | jumla
# Processing Record 22 of Set 11 | biloela
# Processing Record 23 of Set 11 | pondicherry
# Processing Record 24 of Set 11 | almeirim
# Processing Record 25 of Set 11 | uruguaiana
# Processing Record 26 of Set 11 | miles city
# Processing Record 27 of Set 11 | dryden
# Processing Record 28 of Set 11 | basco
# Processing Record 29 of Set 11 | yeppoon
# City not found. Skipping...
# Processing Record 30 of Set 11 | antofagasta
# Processing Record 31 of Set 11 | aykhal
# Processing Record 32 of Set 11 | salalah
# Processing Record 33 of Set 11 | dauphin
# Processing Record 34 of Set 11 | vila
# Processing Record 35 of Set 11 | minsk
# Processing Record 36 of Set 11 | znamenskoye
# Processing Record 37 of Set 11 | garowe
# Processing Record 38 of Set 11 | lucea
# Processing Record 39 of Set 11 | coquimbo
# Processing Record 40 of Set 11 | lianzhou
# Processing Record 41 of Set 11 | huangmei
# Processing Record 42 of Set 11 | bowen
# Processing Record 43 of Set 11 | la ronge
# Processing Record 44 of Set 11 | uwajima
# Processing Record 45 of Set 11 | rosarito
# City not found. Skipping...
# Processing Record 46 of Set 11 | namtsy
# Processing Record 47 of Set 11 | singaparna
# Processing Record 48 of Set 11 | fort frances
# Processing Record 49 of Set 11 | hamamatsu
# Processing Record 1 of Set 12 | belokurikha
# Processing Record 2 of Set 12 | saint anthony
# Processing Record 3 of Set 12 | san juan
# Processing Record 4 of Set 12 | rodniki
# Processing Record 5 of Set 12 | tapes
# Processing Record 6 of Set 12 | riachao
# City not found. Skipping...
# Processing Record 7 of Set 12 | ixtapa
# Processing Record 8 of Set 12 | kampene
# Processing Record 9 of Set 12 | siirt
# City not found. Skipping...
# Processing Record 10 of Set 12 | goianinha
# Processing Record 11 of Set 12 | orgita
# Processing Record 12 of Set 12 | padang
# Processing Record 13 of Set 12 | durango
# Processing Record 14 of Set 12 | rio gallegos
# Processing Record 15 of Set 12 | giyani
# Processing Record 16 of Set 12 | bela
# Processing Record 17 of Set 12 | honiara
# Processing Record 18 of Set 12 | bull savanna
# Processing Record 19 of Set 12 | kristiinankaupunki
# City not found. Skipping...
# Processing Record 20 of Set 12 | jalu
# Processing Record 21 of Set 12 | huarmey
# City not found. Skipping...
# Processing Record 22 of Set 12 | hue
# Processing Record 23 of Set 12 | turrialba
# Processing Record 24 of Set 12 | olinda
# Processing Record 25 of Set 12 | catamarca
# Processing Record 26 of Set 12 | tulum
# Processing Record 27 of Set 12 | chany
# Processing Record 28 of Set 12 | nyurba
# Processing Record 29 of Set 12 | cidreira
# Processing Record 30 of Set 12 | sioux lookout
# Processing Record 31 of Set 12 | lethem
# Processing Record 32 of Set 12 | pitimbu
# Processing Record 33 of Set 12 | kampot
# Processing Record 34 of Set 12 | necochea
# Processing Record 35 of Set 12 | meadow lake

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create the data frame for the weather data
raw_data = pd.DataFrame({
    "City" : pd.Series(city_names),
    "Cloudiness" : pd.Series(cloudiness),
    "Country" : pd.Series(country),
    "Date" : pd.Series(date),
    "Humidity" : pd.Series(humidity),
    "Lat" : pd.Series(lat),
    "Lng" : pd.Series(lng),
    "Max Temp" : pd.Series(max_temp),
    "Wind Speed" : pd.Series(wind_speed)
})
raw_data
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Hong Kong          75      HK  1604805035        56  22.29  114.16
# 1           Nome          90      US  1604805035        80  64.50 -165.41
# 2        Rikitea         100      PF  1604805036        74 -23.12 -134.97
# 3    George Town          20      MY  1604804993        74   5.41  100.34
# 4       Phonhong          20      LA  1604805036        61  18.50  102.42
# ..           ...         ...     ...         ...       ...    ...     ...
# 569       Lethem          27      GY  1604805195        77   3.38  -59.80
# 570      Pitimbu          75      BR  1604805195        83  -7.47  -34.81
# 571       Kampot          40      KH  1604805051        78  10.62  104.18
# 572     Necochea           0      AR  1604805196        92 -38.55  -58.74
# 573  Meadow Lake          75      US  1604805196        27  34.80 -106.54
#
#      Max Temp  Wind Speed
# 0       79.00        1.01
# 1       35.60        3.58
# 2       71.74       17.85
# 3       86.00        4.70
# 4       82.40        2.24
# ..        ...         ...
# 569     79.66        2.91
# 570     78.80       10.29
# 571     82.40        1.12
# 572     55.00        4.00
# 573     66.00       11.41
#
# [574 rows x 9 columns]

# %%
# remove incomplete data entries
city_data = raw_data.dropna(how= "any")
city_data
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Hong Kong          75      HK  1604805035        56  22.29  114.16
# 1           Nome          90      US  1604805035        80  64.50 -165.41
# 2        Rikitea         100      PF  1604805036        74 -23.12 -134.97
# 3    George Town          20      MY  1604804993        74   5.41  100.34
# 4       Phonhong          20      LA  1604805036        61  18.50  102.42
# ..           ...         ...     ...         ...       ...    ...     ...
# 569       Lethem          27      GY  1604805195        77   3.38  -59.80
# 570      Pitimbu          75      BR  1604805195        83  -7.47  -34.81
# 571       Kampot          40      KH  1604805051        78  10.62  104.18
# 572     Necochea           0      AR  1604805196        92 -38.55  -58.74
# 573  Meadow Lake          75      US  1604805196        27  34.80 -106.54
#
#      Max Temp  Wind Speed
# 0       79.00        1.01
# 1       35.60        3.58
# 2       71.74       17.85
# 3       86.00        4.70
# 4       82.40        2.24
# ..        ...         ...
# 569     79.66        2.91
# 570     78.80       10.29
# 571     82.40        1.12
# 572     55.00        4.00
# 573     66.00       11.41
#
# [574 rows x 9 columns]

# %%
# display the count of each data entry attribute
city_data.count()
# Out:
# City          574
# Cloudiness    574
# Country       574
# Date          574
# Humidity      574
# Lat           574
# Lng           574
# Max Temp      574
# Wind Speed    574
# dtype: int64

# %%
# direct the data into an output csv file
city_data.to_csv(output_data_file)

# %%
# summarize the weather data
city_data.describe()
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count  574.000000  5.740000e+02  574.000000  574.000000  574.000000
# mean    47.620209  1.604805e+09   73.799652   20.654408   21.079233
# std     39.380703  8.135393e+01   19.122822   33.483752   91.008305
# min      0.000000  1.604805e+09    7.000000  -54.800000 -175.200000
# 25%      1.000000  1.604805e+09   63.000000   -6.220000  -58.642500
# 50%     42.000000  1.604805e+09   78.000000   24.360000   27.070000
# 75%     90.000000  1.604805e+09   88.000000   50.552500  100.347500
# max    100.000000  1.604805e+09  100.000000   78.220000  179.320000
#
#          Max Temp  Wind Speed
# count  574.000000  574.000000
# mean    58.055505    8.424930
# std     22.783368    6.115157
# min    -22.880000    0.380000
# 25%     42.800000    4.120000
# 50%     63.525000    6.930000
# 75%     76.745000   11.410000
# max     98.440000   48.320000

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Plot the scattered plot between the relationships of city latitude and max tempurature
plt.scatter(city_data["Lat"], city_data["Max Temp"], edgecolor = "black", facecolor = "cornflowerblue")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature (11/07/20)")
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Plot the scattered plot between the relationships of city latitude and humidity
plt.scatter(city_data["Lat"], city_data["Humidity"], edgecolor = "black", facecolor = "cornflowerblue")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (11/07/20)")
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Plot the scattered plot between the relationships of city latitude and Cloudiness
plt.scatter(city_data["Lat"], city_data["Cloudiness"], edgecolor = "black", facecolor = "cornflowerblue")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (11/07/20)")
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Plot the scattered plot between the relationships of city latitude and wind speed
plt.scatter(city_data["Lat"], city_data["Wind Speed"], edgecolor = "black", facecolor = "cornflowerblue")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed (11/07/20)")
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#Hemisphere (greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude):
northern = city_data[city_data["Lat"] >= 0]
southern = city_data[city_data["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# compute the regression of the relationships between city latitude and max tempurature of Northern Hemisphere
regression1 = sts.linregress(northern["Lat"], northern["Max Temp"])
regression_line1 = regression1[0] * (northern["Lat"]) + regression1[1]
r_value1 = sts.pearsonr(northern["Lat"], northern["Max Temp"])[0]

# %%
# plot the scattered plot and the regression line between city latitude and max tempurature of Northern Hemisphere
print(f"The r-value is: {r_value1}")
plt.scatter(northern["Lat"], northern["Max Temp"], edgecolor = "black", facecolor = "cornflowerblue")
plt.plot(northern["Lat"], regression_line1, color = "red")
plt.annotate("y = " + str(round(regression1[0],2)) + "x + " + str(round(regression1[1],2)), (12,20), size = 13, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature of Northern Hemisphere")
plt.show()
# Out:
# The r-value is: -0.876142068314379

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# compute the regression of the relationships between city latitude and max tempurature of Southern Hemisphere
regression2 = sts.linregress(southern["Lat"], southern["Max Temp"])
regression_line2 = regression2[0] * (southern["Lat"]) + regression2[1]
r_value2 = sts.pearsonr(southern["Lat"], southern["Max Temp"])[0]

# %%
# plot the scattered plot and the regression line between city latitude and max tempurature of Southern Hemisphere
print(f"The r-value is: {r_value2}")
plt.scatter(southern["Lat"], southern["Max Temp"], edgecolor = "black", facecolor = "cornflowerblue")
plt.plot(southern["Lat"], regression_line2, color = "red")
plt.annotate("y = " + str(round(regression2[0],2)) + "x + " + str(round(regression2[1],2)), (-50,90), size = 13, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature of Southern Hemisphere")
plt.show()
# Out:
# The r-value is: 0.6557212262178516

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
regression3 = sts.linregress(northern["Lat"], northern["Humidity"])
regression_line3 = regression3[0] * (northern["Lat"]) + regression3[1]
r_value3 = sts.pearsonr(northern["Lat"], northern["Humidity"])[0]

# %%
# plot the scattered plot and the regression line between city latitude and humidity of Northern Hemisphere
print(f"The r-value is: {r_value3}")
plt.scatter(northern["Lat"], northern["Humidity"], edgecolor = "black", facecolor = "cornflowerblue")
plt.plot(northern["Lat"], regression_line3, color = "red")
plt.annotate("y = " + str(round(regression3[0],2)) + "x + " + str(round(regression3[1],2)), (50,20), size = 13, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity of Northern Hemisphere")
plt.show()
# Out:
# The r-value is: 0.29351904555348796

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
regression4 = sts.linregress(southern["Lat"], southern["Humidity"])
regression_line4 = regression4[0] * (southern["Lat"]) + regression4[1]
r_value4 = sts.pearsonr(southern["Lat"], southern["Humidity"])[0]

# %%
print(f"The r-value is: {r_value4}")
plt.scatter(southern["Lat"], southern["Humidity"], edgecolor = "black", facecolor = "cornflowerblue")
plt.plot(southern["Lat"], regression_line4, color = "red")
plt.annotate("y = " + str(round(regression4[0],2)) + "x + " + str(round(regression4[1],2)), (-20,20), size = 13, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity of Southern Hemisphere")
plt.show()
# Out:
# The r-value is: 0.2650267862772795

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
regression5 = sts.linregress(northern["Lat"], northern["Cloudiness"])
regression_line5 = regression5[0] * (northern["Lat"]) + regression5[1]
r_value5 = sts.pearsonr(northern["Lat"], northern["Cloudiness"])[0]

# %%
print(f"The r-value is: {r_value5}")
plt.scatter(northern["Lat"], northern["Cloudiness"], edgecolor = "black", facecolor = "cornflowerblue")
plt.plot(northern["Lat"], regression_line5, color = "red")
plt.annotate("y = " + str(round(regression5[0],2)) + "x + " + str(round(regression5[1],2)), (20,60), size = 13, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness of Northern Hemisphere")
plt.show()
# Out:
# The r-value is: 0.28294435766135667

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
regression6 = sts.linregress(southern["Lat"], southern["Cloudiness"])
regression_line6 = regression6[0] * (southern["Lat"]) + regression6[1]
r_value6 = sts.pearsonr(southern["Lat"], southern["Cloudiness"])[0]

# %%
print(f"The r-value is: {r_value6}")
plt.scatter(southern["Lat"], southern["Cloudiness"], edgecolor = "black", facecolor = "cornflowerblue")
plt.plot(southern["Lat"], regression_line6, color = "red")
plt.annotate("y = " + str(round(regression6[0],2)) + "x + " + str(round(regression6[1],2)), (-55,65), size = 13, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness of Southern Hemisphere")
plt.show()
# Out:
# The r-value is: 0.4280291969229101

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
regression7 = sts.linregress(northern["Lat"], northern["Wind Speed"])
regression_line7 = regression7[0] * (northern["Lat"]) + regression7[1]
r_value7 = sts.pearsonr(northern["Lat"], northern["Wind Speed"])[0]

# %%
print(f"The r-value is: {r_value7}")
plt.scatter(northern["Lat"], northern["Wind Speed"], edgecolor = "black", facecolor = "cornflowerblue")
plt.plot(northern["Lat"], regression_line7, color = "red")
plt.annotate("y = " + str(round(regression7[0],2)) + "x + " + str(round(regression7[1],2)), (20,40), size = 13, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed of Northern Hemisphere")
plt.show()
# Out:
# The r-value is: 0.22165739059725675

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
regression8 = sts.linregress(southern["Lat"], southern["Wind Speed"])
regression_line8 = regression8[0] * (southern["Lat"]) + regression8[1]
r_value8 = sts.pearsonr(southern["Lat"], southern["Wind Speed"])[0]

# %%
print(f"The r-value is: {r_value8}")
plt.scatter(southern["Lat"], southern["Wind Speed"], edgecolor = "black", facecolor = "cornflowerblue")
plt.plot(southern["Lat"], regression_line8, color = "red")
plt.annotate("y = " + str(round(regression8[0],2)) + "x + " + str(round(regression8[1],2)), (-20,20), size = 13, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed of Southern Hemisphere")
plt.show()
# Out:
# The r-value is: -0.3571321897090898
