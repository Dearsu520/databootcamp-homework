# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as sts

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 621

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Initialize empty lists for the building of the dataframe
city_names = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# %%
# Build for loop to retrieve data for each city in the cities list
record = 1
set_number = 1
print("Beginning Data Retrieval")
print("-----------------------------")
for city in cities:
    # Build query URL and request results in Fahrenheit
    query = city
    units = "imperial"
    # Retrieve the weather data from the URL
    base_url = "http://api.openweathermap.org/data/2.5/weather?"
    parameters = f"appid={api_key}&q={query}&units={units}"
    url = base_url + parameters 
    response = requests.get(url).json()
    # If the response is not 200, skip the current data entry
    if response["cod"] != 200: 
        print("City not found. Skipping...")
        pass
    # Otherwise, append the empty lists with their corresponding data attributes
    else: 
        city_names.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        print(f"Processing Record {record} of Set {set_number} | {city}")
        record += 1
        # Create a time sleep to avoid API overrunning limit
        if record == 50:
            time.sleep(3)
            record = 1
            set_number += 1
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | konyshevka
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | majene
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | warrington
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | linjiang
# Processing Record 9 of Set 1 | wamba
# Processing Record 10 of Set 1 | alofi
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | klaksvik
# Processing Record 14 of Set 1 | faanui
# Processing Record 15 of Set 1 | bonavista
# Processing Record 16 of Set 1 | kavieng
# Processing Record 17 of Set 1 | iki-burul
# City not found. Skipping...
# Processing Record 18 of Set 1 | goderich
# Processing Record 19 of Set 1 | grand gaube
# Processing Record 20 of Set 1 | tecpan
# Processing Record 21 of Set 1 | maiduguri
# City not found. Skipping...
# Processing Record 22 of Set 1 | alta floresta
# Processing Record 23 of Set 1 | saskylakh
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | maraa
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | tucumcari
# Processing Record 28 of Set 1 | poum
# Processing Record 29 of Set 1 | zagora
# Processing Record 30 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | yulara
# Processing Record 33 of Set 1 | santa maria
# Processing Record 34 of Set 1 | airai
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | severo-kurilsk
# City not found. Skipping...
# Processing Record 40 of Set 1 | nambour
# Processing Record 41 of Set 1 | rotifunk
# Processing Record 42 of Set 1 | pitimbu
# Processing Record 43 of Set 1 | sembe
# Processing Record 44 of Set 1 | longyearbyen
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | mount gambier
# City not found. Skipping...
# Processing Record 48 of Set 1 | karaton
# Processing Record 49 of Set 1 | hami
# Processing Record 1 of Set 2 | medeiros neto
# Processing Record 2 of Set 2 | thompson
# Processing Record 3 of Set 2 | kirksville
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | mehamn
# Processing Record 6 of Set 2 | luderitz
# Processing Record 7 of Set 2 | leningradskiy
# Processing Record 8 of Set 2 | bathsheba
# Processing Record 9 of Set 2 | tortoli
# Processing Record 10 of Set 2 | namibe
# Processing Record 11 of Set 2 | banyo
# Processing Record 12 of Set 2 | koson
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | banjar
# Processing Record 15 of Set 2 | elko
# Processing Record 16 of Set 2 | bambous virieux
# Processing Record 17 of Set 2 | punta arenas
# Processing Record 18 of Set 2 | sola
# Processing Record 19 of Set 2 | temple terrace
# Processing Record 20 of Set 2 | lanquin
# Processing Record 21 of Set 2 | port augusta
# Processing Record 22 of Set 2 | bogatyye saby
# City not found. Skipping...
# Processing Record 23 of Set 2 | mahebourg
# Processing Record 24 of Set 2 | ostrovnoy
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | statesboro
# Processing Record 28 of Set 2 | upernavik
# Processing Record 29 of Set 2 | gwadar
# Processing Record 30 of Set 2 | lompoc
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | soyo
# Processing Record 34 of Set 2 | anloga
# Processing Record 35 of Set 2 | kahului
# Processing Record 36 of Set 2 | castro
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | udimskiy
# Processing Record 39 of Set 2 | otradnoye
# Processing Record 40 of Set 2 | saint george
# Processing Record 41 of Set 2 | hobyo
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | bengkulu
# Processing Record 45 of Set 2 | severnoye
# Processing Record 46 of Set 2 | gobabis
# Processing Record 47 of Set 2 | avera
# Processing Record 48 of Set 2 | talnakh
# City not found. Skipping...
# Processing Record 49 of Set 2 | vaini
# Processing Record 1 of Set 3 | maceio
# City not found. Skipping...
# Processing Record 2 of Set 3 | tiksi
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | te anau
# City not found. Skipping...
# Processing Record 5 of Set 3 | arraial do cabo
# Processing Record 6 of Set 3 | humaita
# City not found. Skipping...
# Processing Record 7 of Set 3 | salta
# Processing Record 8 of Set 3 | ifanadiana
# Processing Record 9 of Set 3 | la asuncion
# Processing Record 10 of Set 3 | potsdam
# Processing Record 11 of Set 3 | hauterive
# Processing Record 12 of Set 3 | pasighat
# Processing Record 13 of Set 3 | vardo
# Processing Record 14 of Set 3 | kodiak
# Processing Record 15 of Set 3 | leeuwarden
# Processing Record 16 of Set 3 | codrington
# Processing Record 17 of Set 3 | pudozh
# Processing Record 18 of Set 3 | kalevala
# Processing Record 19 of Set 3 | dikson
# Processing Record 20 of Set 3 | katsuura
# Processing Record 21 of Set 3 | east london
# Processing Record 22 of Set 3 | sakakah
# Processing Record 23 of Set 3 | guerrero negro
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | iwanai
# Processing Record 26 of Set 3 | sitangkai
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | clyde river
# Processing Record 29 of Set 3 | corinto
# City not found. Skipping...
# Processing Record 30 of Set 3 | luanda
# Processing Record 31 of Set 3 | nome
# Processing Record 32 of Set 3 | padang
# Processing Record 33 of Set 3 | nanortalik
# Processing Record 34 of Set 3 | sorland
# City not found. Skipping...
# Processing Record 35 of Set 3 | saint anthony
# Processing Record 36 of Set 3 | georgetown
# Processing Record 37 of Set 3 | tazmalt
# Processing Record 38 of Set 3 | norman wells
# Processing Record 39 of Set 3 | pangai
# Processing Record 40 of Set 3 | maple creek
# Processing Record 41 of Set 3 | ilebo
# Processing Record 42 of Set 3 | sawakin
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | souillac
# Processing Record 45 of Set 3 | topolevo
# Processing Record 46 of Set 3 | tab
# Processing Record 47 of Set 3 | kuah
# Processing Record 48 of Set 3 | parabel
# Processing Record 49 of Set 3 | fairbanks
# Processing Record 1 of Set 4 | balassagyarmat
# Processing Record 2 of Set 4 | jamestown
# Processing Record 3 of Set 4 | chute-aux-outardes
# Processing Record 4 of Set 4 | qaqortoq
# Processing Record 5 of Set 4 | carnarvon
# Processing Record 6 of Set 4 | umm kaddadah
# Processing Record 7 of Set 4 | nang rong
# City not found. Skipping...
# Processing Record 8 of Set 4 | leh
# Processing Record 9 of Set 4 | ponta do sol
# Processing Record 10 of Set 4 | coihaique
# Processing Record 11 of Set 4 | ahipara
# Processing Record 12 of Set 4 | vila franca do campo
# City not found. Skipping...
# Processing Record 13 of Set 4 | lianzhou
# Processing Record 14 of Set 4 | half moon bay
# Processing Record 15 of Set 4 | chabahar
# Processing Record 16 of Set 4 | winnemucca
# Processing Record 17 of Set 4 | iqaluit
# Processing Record 18 of Set 4 | alice springs
# Processing Record 19 of Set 4 | burns lake
# Processing Record 20 of Set 4 | flinders
# City not found. Skipping...
# Processing Record 21 of Set 4 | cururupu
# Processing Record 22 of Set 4 | camacha
# Processing Record 23 of Set 4 | ixtapa
# Processing Record 24 of Set 4 | oksfjord
# Processing Record 25 of Set 4 | emirdag
# Processing Record 26 of Set 4 | cabo san lucas
# Processing Record 27 of Set 4 | ome
# Processing Record 28 of Set 4 | hithadhoo
# Processing Record 29 of Set 4 | svetlogorsk
# Processing Record 30 of Set 4 | torbay
# Processing Record 31 of Set 4 | faya
# City not found. Skipping...
# Processing Record 32 of Set 4 | mahajanga
# City not found. Skipping...
# Processing Record 33 of Set 4 | navolato
# Processing Record 34 of Set 4 | sitka
# Processing Record 35 of Set 4 | ust-nera
# Processing Record 36 of Set 4 | bethel
# City not found. Skipping...
# Processing Record 37 of Set 4 | prieska
# Processing Record 38 of Set 4 | freising
# Processing Record 39 of Set 4 | sandovo
# Processing Record 40 of Set 4 | berlevag
# Processing Record 41 of Set 4 | san patricio
# Processing Record 42 of Set 4 | high level
# Processing Record 43 of Set 4 | ciudad bolivar
# Processing Record 44 of Set 4 | duncan
# Processing Record 45 of Set 4 | palu
# Processing Record 46 of Set 4 | tuy hoa
# Processing Record 47 of Set 4 | cherskiy
# Processing Record 48 of Set 4 | kamenka
# Processing Record 49 of Set 4 | dubbo
# Processing Record 1 of Set 5 | shenjiamen
# Processing Record 2 of Set 5 | caruray
# Processing Record 3 of Set 5 | kalmunai
# City not found. Skipping...
# Processing Record 4 of Set 5 | koutiala
# Processing Record 5 of Set 5 | gardanne
# Processing Record 6 of Set 5 | la ronge
# Processing Record 7 of Set 5 | lorengau
# Processing Record 8 of Set 5 | skibotn
# Processing Record 9 of Set 5 | chanthaburi
# Processing Record 10 of Set 5 | odweyne
# Processing Record 11 of Set 5 | sept-iles
# Processing Record 12 of Set 5 | aksu
# City not found. Skipping...
# Processing Record 13 of Set 5 | tenenkou
# Processing Record 14 of Set 5 | pemangkat
# Processing Record 15 of Set 5 | bend
# Processing Record 16 of Set 5 | houma
# Processing Record 17 of Set 5 | paragominas
# Processing Record 18 of Set 5 | gimli
# Processing Record 19 of Set 5 | bilibino
# Processing Record 20 of Set 5 | sistranda
# Processing Record 21 of Set 5 | pitea
# Processing Record 22 of Set 5 | bloomingdale
# Processing Record 23 of Set 5 | enshi
# Processing Record 24 of Set 5 | dubai
# Processing Record 25 of Set 5 | naze
# Processing Record 26 of Set 5 | orito
# Processing Record 27 of Set 5 | tura
# Processing Record 28 of Set 5 | bonnyville
# Processing Record 29 of Set 5 | tromso
# City not found. Skipping...
# Processing Record 30 of Set 5 | manaia
# Processing Record 31 of Set 5 | vestmannaeyjar
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 5 | nakasongola
# Processing Record 33 of Set 5 | awjilah
# Processing Record 34 of Set 5 | victoria
# Processing Record 35 of Set 5 | constitucion
# Processing Record 36 of Set 5 | broome
# Processing Record 37 of Set 5 | finnsnes
# Processing Record 38 of Set 5 | nyanza
# Processing Record 39 of Set 5 | adrar
# Processing Record 40 of Set 5 | skibbereen
# Processing Record 41 of Set 5 | bambanglipuro
# Processing Record 42 of Set 5 | rawson
# Processing Record 43 of Set 5 | hasaki
# City not found. Skipping...
# Processing Record 44 of Set 5 | bandarbeyla
# Processing Record 45 of Set 5 | ancud
# Processing Record 46 of Set 5 | aklavik
# Processing Record 47 of Set 5 | tondano
# Processing Record 48 of Set 5 | kayiry
# Processing Record 49 of Set 5 | sungaipenuh
# Processing Record 1 of Set 6 | hohhot
# Processing Record 2 of Set 6 | cintalapa
# City not found. Skipping...
# Processing Record 3 of Set 6 | gorele
# Processing Record 4 of Set 6 | muros
# Processing Record 5 of Set 6 | piro
# Processing Record 6 of Set 6 | korla
# City not found. Skipping...
# Processing Record 7 of Set 6 | kutum
# City not found. Skipping...
# Processing Record 8 of Set 6 | burgos
# Processing Record 9 of Set 6 | port lincoln
# Processing Record 10 of Set 6 | esperance
# Processing Record 11 of Set 6 | tuatapere
# Processing Record 12 of Set 6 | meulaboh
# Processing Record 13 of Set 6 | qasigiannguit
# Processing Record 14 of Set 6 | gat
# Processing Record 15 of Set 6 | vanimo
# Processing Record 16 of Set 6 | ugoofaaru
# Processing Record 17 of Set 6 | port arthur
# Processing Record 18 of Set 6 | farafangana
# Processing Record 19 of Set 6 | haines junction
# Processing Record 20 of Set 6 | cleveland
# Processing Record 21 of Set 6 | kaohsiung
# Processing Record 22 of Set 6 | coihueco
# Processing Record 23 of Set 6 | ulaangom
# Processing Record 24 of Set 6 | galle
# Processing Record 25 of Set 6 | wexford
# City not found. Skipping...
# Processing Record 26 of Set 6 | kaniama
# Processing Record 27 of Set 6 | lasa
# Processing Record 28 of Set 6 | okhotsk
# Processing Record 29 of Set 6 | tongren
# Processing Record 30 of Set 6 | jagdalpur
# Processing Record 31 of Set 6 | milkovo
# Processing Record 32 of Set 6 | novyy urengoy
# Processing Record 33 of Set 6 | solnechnyy
# Processing Record 34 of Set 6 | moose jaw
# Processing Record 35 of Set 6 | westport
# Processing Record 36 of Set 6 | shetpe
# Processing Record 37 of Set 6 | fallon
# Processing Record 38 of Set 6 | puerto narino
# Processing Record 39 of Set 6 | riyadh
# Processing Record 40 of Set 6 | elliot lake
# Processing Record 41 of Set 6 | viedma
# Processing Record 42 of Set 6 | chokurdakh
# Processing Record 43 of Set 6 | noumea
# Processing Record 44 of Set 6 | san francisco
# Processing Record 45 of Set 6 | zhanaozen
# Processing Record 46 of Set 6 | cabra
# Processing Record 47 of Set 6 | el bagre
# Processing Record 48 of Set 6 | anchorage
# Processing Record 49 of Set 6 | inuvik
# Processing Record 1 of Set 7 | geraldton
# Processing Record 2 of Set 7 | praia
# Processing Record 3 of Set 7 | woodward
# Processing Record 4 of Set 7 | kaitangata
# Processing Record 5 of Set 7 | riachao das neves
# Processing Record 6 of Set 7 | mar del plata
# Processing Record 7 of Set 7 | chebarkul
# Processing Record 8 of Set 7 | tomatlan
# Processing Record 9 of Set 7 | mandan
# Processing Record 10 of Set 7 | genhe
# Processing Record 11 of Set 7 | mbouda
# Processing Record 12 of Set 7 | vieques
# Processing Record 13 of Set 7 | banda aceh
# Processing Record 14 of Set 7 | chuy
# Processing Record 15 of Set 7 | djibo
# Processing Record 16 of Set 7 | jipijapa
# Processing Record 17 of Set 7 | margate
# Processing Record 18 of Set 7 | salalah
# Processing Record 19 of Set 7 | chernihiv
# Processing Record 20 of Set 7 | cidreira
# City not found. Skipping...
# Processing Record 21 of Set 7 | mindelo
# City not found. Skipping...
# Processing Record 22 of Set 7 | nelson bay
# Processing Record 23 of Set 7 | rafai
# Processing Record 24 of Set 7 | bagula
# Processing Record 25 of Set 7 | kaka
# Processing Record 26 of Set 7 | shenzhen
# Processing Record 27 of Set 7 | kolomna
# City not found. Skipping...
# Processing Record 28 of Set 7 | agadez
# Processing Record 29 of Set 7 | uyuni
# Processing Record 30 of Set 7 | jalpan
# Processing Record 31 of Set 7 | ilulissat
# Processing Record 32 of Set 7 | vilhena
# Processing Record 33 of Set 7 | isangel
# Processing Record 34 of Set 7 | samarinda
# Processing Record 35 of Set 7 | manokwari
# Processing Record 36 of Set 7 | mazeikiai
# Processing Record 37 of Set 7 | pankrushikha
# Processing Record 38 of Set 7 | port hardy
# Processing Record 39 of Set 7 | magaria
# Processing Record 40 of Set 7 | butaritari
# Processing Record 41 of Set 7 | stranda
# City not found. Skipping...
# Processing Record 42 of Set 7 | ustynivka
# Processing Record 43 of Set 7 | tarko-sale
# Processing Record 44 of Set 7 | devonport
# City not found. Skipping...
# Processing Record 45 of Set 7 | komsomolskiy
# Processing Record 46 of Set 7 | oktyabrskoye
# Processing Record 47 of Set 7 | tecoanapa
# Processing Record 48 of Set 7 | banposh
# Processing Record 49 of Set 7 | pontianak
# Processing Record 1 of Set 8 | pevek
# Processing Record 2 of Set 8 | strezhevoy
# Processing Record 3 of Set 8 | sayat
# Processing Record 4 of Set 8 | havre-saint-pierre
# City not found. Skipping...
# Processing Record 5 of Set 8 | vokhtoga
# Processing Record 6 of Set 8 | bertoua
# Processing Record 7 of Set 8 | nicoya
# Processing Record 8 of Set 8 | lavrentiya
# Processing Record 9 of Set 8 | sinnamary
# Processing Record 10 of Set 8 | eyl
# Processing Record 11 of Set 8 | zeya
# Processing Record 12 of Set 8 | manzanillo
# Processing Record 13 of Set 8 | porto novo
# Processing Record 14 of Set 8 | colesberg
# Processing Record 15 of Set 8 | rabo de peixe
# Processing Record 16 of Set 8 | lucea
# Processing Record 17 of Set 8 | catalina
# City not found. Skipping...
# Processing Record 18 of Set 8 | sur
# Processing Record 19 of Set 8 | gao
# Processing Record 20 of Set 8 | imbituba
# Processing Record 21 of Set 8 | yatou
# Processing Record 22 of Set 8 | sturgis
# Processing Record 23 of Set 8 | champerico
# Processing Record 24 of Set 8 | buritizeiro
# Processing Record 25 of Set 8 | broken hill
# Processing Record 26 of Set 8 | teya
# City not found. Skipping...
# Processing Record 27 of Set 8 | gravdal
# Processing Record 28 of Set 8 | kavaratti
# Processing Record 29 of Set 8 | halifax
# Processing Record 30 of Set 8 | vamvakou
# Processing Record 31 of Set 8 | garissa
# Processing Record 32 of Set 8 | amposta
# Processing Record 33 of Set 8 | nizhniy kuranakh
# Processing Record 34 of Set 8 | tual
# City not found. Skipping...
# Processing Record 35 of Set 8 | tacuta
# Processing Record 36 of Set 8 | kuala pilah
# Processing Record 37 of Set 8 | rocha
# Processing Record 38 of Set 8 | beipiao
# Processing Record 39 of Set 8 | chimbote
# Processing Record 40 of Set 8 | fortuna
# Processing Record 41 of Set 8 | dingle
# Processing Record 42 of Set 8 | orsk
# Processing Record 43 of Set 8 | steamboat springs
# Processing Record 44 of Set 8 | port-gentil
# Processing Record 45 of Set 8 | belogorsk
# Processing Record 46 of Set 8 | sabancuy
# Processing Record 47 of Set 8 | batouri
# Processing Record 48 of Set 8 | diebougou
# Processing Record 49 of Set 8 | santarem
# Processing Record 1 of Set 9 | palembang
# Processing Record 2 of Set 9 | valley city
# Processing Record 3 of Set 9 | huarmey
# Processing Record 4 of Set 9 | moron
# Processing Record 5 of Set 9 | hillsboro
# Processing Record 6 of Set 9 | karatau
# Processing Record 7 of Set 9 | pyay
# Processing Record 8 of Set 9 | hambantota
# Processing Record 9 of Set 9 | narsaq
# Processing Record 10 of Set 9 | chimoio
# Processing Record 11 of Set 9 | nuuk
# Processing Record 12 of Set 9 | yining
# Processing Record 13 of Set 9 | yar-sale
# Processing Record 14 of Set 9 | marawi
# Processing Record 15 of Set 9 | prince rupert
# Processing Record 16 of Set 9 | gazli
# Processing Record 17 of Set 9 | tongling
# Processing Record 18 of Set 9 | shaunavon
# Processing Record 19 of Set 9 | ossining
# Processing Record 20 of Set 9 | rottingdean
# Processing Record 21 of Set 9 | palauig
# Processing Record 22 of Set 9 | mitsamiouli
# Processing Record 23 of Set 9 | saint-michel-des-saints
# City not found. Skipping...
# Processing Record 24 of Set 9 | shieli
# Processing Record 25 of Set 9 | kalvarija
# Processing Record 26 of Set 9 | hirado
# Processing Record 27 of Set 9 | beyneu
# Processing Record 28 of Set 9 | bossangoa
# Processing Record 29 of Set 9 | oranjemund
# Processing Record 30 of Set 9 | basco
# Processing Record 31 of Set 9 | verkhoyansk
# City not found. Skipping...
# Processing Record 32 of Set 9 | makakilo city
# Processing Record 33 of Set 9 | poltavka
# Processing Record 34 of Set 9 | terre-de-bas
# Processing Record 35 of Set 9 | zaysan
# Processing Record 36 of Set 9 | pisco
# Processing Record 37 of Set 9 | sayyan
# Processing Record 38 of Set 9 | santa vitoria do palmar
# Processing Record 39 of Set 9 | lincoln
# Processing Record 40 of Set 9 | oshakati
# Processing Record 41 of Set 9 | torrington
# Processing Record 42 of Set 9 | shelburne
# Processing Record 43 of Set 9 | sovetskiy
# Processing Record 44 of Set 9 | saint-pierre
# Processing Record 45 of Set 9 | grenfell
# Processing Record 46 of Set 9 | invermere
# Processing Record 47 of Set 9 | batagay
# Processing Record 48 of Set 9 | kiama
# Processing Record 49 of Set 9 | yumen
# Processing Record 1 of Set 10 | mandalgovi
# Processing Record 2 of Set 10 | gulu
# Processing Record 3 of Set 10 | japura
# Processing Record 4 of Set 10 | mahibadhoo
# Processing Record 5 of Set 10 | itabirito
# Processing Record 6 of Set 10 | cairns
# Processing Record 7 of Set 10 | huilong
# Processing Record 8 of Set 10 | primorsk
# Processing Record 9 of Set 10 | ornskoldsvik
# Processing Record 10 of Set 10 | whakatane
# Processing Record 11 of Set 10 | nusaybin
# Processing Record 12 of Set 10 | cayenne
# Processing Record 13 of Set 10 | carbonia
# Processing Record 14 of Set 10 | mujiayingzi
# Processing Record 15 of Set 10 | jiuquan
# Processing Record 16 of Set 10 | great bend
# Processing Record 17 of Set 10 | palakkad
# Processing Record 18 of Set 10 | acapulco
# Processing Record 19 of Set 10 | ouesso
# Processing Record 20 of Set 10 | vallenar
# Processing Record 21 of Set 10 | kansanshi
# Processing Record 22 of Set 10 | grinnell
# Processing Record 23 of Set 10 | krasnyy chikoy
# Processing Record 24 of Set 10 | kudahuvadhoo
# Processing Record 25 of Set 10 | bacolod
# Processing Record 26 of Set 10 | pahrump
# City not found. Skipping...
# Processing Record 27 of Set 10 | norrtalje
# Processing Record 28 of Set 10 | lethem
# Processing Record 29 of Set 10 | onda
# Processing Record 30 of Set 10 | palencia
# Processing Record 31 of Set 10 | vaitape
# Processing Record 32 of Set 10 | maumere
# Processing Record 33 of Set 10 | cullera
# Processing Record 34 of Set 10 | sidi ali
# Processing Record 35 of Set 10 | gigmoto
# Processing Record 36 of Set 10 | paracatu
# Processing Record 37 of Set 10 | xichang
# Processing Record 38 of Set 10 | ewo
# Processing Record 39 of Set 10 | kruisfontein
# Processing Record 40 of Set 10 | tall kayf
# Processing Record 41 of Set 10 | la romana
# Processing Record 42 of Set 10 | saint pete beach
# Processing Record 43 of Set 10 | bilma
# Processing Record 44 of Set 10 | kemin
# Processing Record 45 of Set 10 | vila velha
# Processing Record 46 of Set 10 | lagoa
# Processing Record 47 of Set 10 | tukums
# Processing Record 48 of Set 10 | enid
# Processing Record 49 of Set 10 | loiza
# Processing Record 1 of Set 11 | aanekoski
# Processing Record 2 of Set 11 | waipawa
# Processing Record 3 of Set 11 | port blair
# Processing Record 4 of Set 11 | fenoarivo
# Processing Record 5 of Set 11 | panzhihua
# Processing Record 6 of Set 11 | yerofey pavlovich
# Processing Record 7 of Set 11 | araripina
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of Set 11 | temyasovo
# Processing Record 9 of Set 11 | paciran
# Processing Record 10 of Set 11 | axim
# Processing Record 11 of Set 11 | neuquen
# Processing Record 12 of Set 11 | dwarka
# Processing Record 13 of Set 11 | zheleznodorozhnyy
# Processing Record 14 of Set 11 | ewa beach
# Processing Record 15 of Set 11 | soc trang
# City not found. Skipping...
# Processing Record 16 of Set 11 | guozhen
# Processing Record 17 of Set 11 | jalu
# Processing Record 18 of Set 11 | college
# Processing Record 19 of Set 11 | ayorou
# Processing Record 20 of Set 11 | kokoda
# Processing Record 21 of Set 11 | walvis bay
# Processing Record 22 of Set 11 | poquoson
# Processing Record 23 of Set 11 | bangassou
# Processing Record 24 of Set 11 | san quintin
# Processing Record 25 of Set 11 | izyaslav
# Processing Record 26 of Set 11 | kattivakkam
# Processing Record 27 of Set 11 | cervo
# Processing Record 28 of Set 11 | hofn
# Processing Record 29 of Set 11 | paungde
# Processing Record 30 of Set 11 | waddan
# Processing Record 31 of Set 11 | doha
# Processing Record 32 of Set 11 | jiangyou
# City not found. Skipping...
# Processing Record 33 of Set 11 | namatanai
# Processing Record 34 of Set 11 | peniche
# Processing Record 35 of Set 11 | gisborne
# Processing Record 36 of Set 11 | zhigalovo
# Processing Record 37 of Set 11 | irituia
# Processing Record 38 of Set 11 | alvorada
# Processing Record 39 of Set 11 | aktau
# City not found. Skipping...
# Processing Record 40 of Set 11 | asau
# Processing Record 41 of Set 11 | quatre cocos
# Processing Record 42 of Set 11 | manzhouli
# Processing Record 43 of Set 11 | hanna
# Processing Record 44 of Set 11 | puerto escondido
# Processing Record 45 of Set 11 | roma
# Processing Record 46 of Set 11 | opuwo
# Processing Record 47 of Set 11 | zhaotong
# Processing Record 48 of Set 11 | kiomboi
# Processing Record 49 of Set 11 | sechura
# Processing Record 1 of Set 12 | nemuro
# City not found. Skipping...
# Processing Record 2 of Set 12 | ellisras
# Processing Record 3 of Set 12 | byron bay
# Processing Record 4 of Set 12 | lufilufi
# Processing Record 5 of Set 12 | lebanon
# Processing Record 6 of Set 12 | portland
# Processing Record 7 of Set 12 | biak
# Processing Record 8 of Set 12 | kidal
# Processing Record 9 of Set 12 | flagstaff
# Processing Record 10 of Set 12 | los llanos de aridane
# City not found. Skipping...
# Processing Record 11 of Set 12 | genc
# Processing Record 12 of Set 12 | bereda
# City not found. Skipping...
# Processing Record 13 of Set 12 | kyra
# Processing Record 14 of Set 12 | manaure
# Processing Record 15 of Set 12 | rio gallegos
# Processing Record 16 of Set 12 | saint-augustin
# Processing Record 17 of Set 12 | tupaciguara
# Processing Record 18 of Set 12 | tabory
# Processing Record 19 of Set 12 | sao joao da barra
# Processing Record 20 of Set 12 | praia da vitoria
# Processing Record 21 of Set 12 | mangalia
# Processing Record 22 of Set 12 | ponta delgada
# Processing Record 23 of Set 12 | grand island
# Processing Record 24 of Set 12 | ust-tsilma
# Processing Record 25 of Set 12 | languyan
# Processing Record 26 of Set 12 | namwala
# Processing Record 27 of Set 12 | vao
# Processing Record 28 of Set 12 | tupancireta
# Processing Record 29 of Set 12 | pangnirtung
# Processing Record 30 of Set 12 | marion
# Processing Record 31 of Set 12 | matay
# Processing Record 32 of Set 12 | labuhan

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create the data frame for the weather data
raw_data = pd.DataFrame({
    "City" : pd.Series(city_names),
    "Cloudiness" : pd.Series(cloudiness),
    "Country" : pd.Series(country),
    "Date" : pd.Series(date),
    "Humidity" : pd.Series(humidity),
    "Lat" : pd.Series(lat),
    "Lng" : pd.Series(lng),
    "Max Temp" : pd.Series(max_temp),
    "Wind Speed" : pd.Series(wind_speed)
})

# %%
# remove rows containing incomplete or Not a Number data entries
city_data = raw_data.dropna(how= "any")
city_data.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Konyshevka          90      RU  1604813445        87  51.84   35.29
# 1    Hermanus          82      ZA  1604813445        92 -34.42   19.23
# 2        Hilo          90      US  1604813431        88  19.73 -155.09
# 3      Majene           7      ID  1604813446        56  -3.54  118.97
# 4      Albany          40      US  1604813441       100  42.60  -73.97
#
#    Max Temp  Wind Speed
# 0     46.40       11.18
# 1     57.00        1.99
# 2     73.40        8.05
# 3     88.59        7.45
# 4     50.00        3.00

# %%
# display the count of each data entry attribute
city_data.count()
# Out:
# City          571
# Cloudiness    571
# Country       571
# Date          571
# Humidity      571
# Lat           571
# Lng           571
# Max Temp      571
# Wind Speed    571
# dtype: int64

# %%
# Retrieve the data into an output csv file
city_data.to_csv(output_data_file)

# %%
# Summarize the weather data to check if there is any data which its humidity value is over 100%
city_data.describe()
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count  571.000000  5.710000e+02  571.000000  571.000000  571.000000
# mean    47.323993  1.604814e+09   71.765324   21.069930   14.559527
# std     38.819986  7.859816e+01   20.338821   32.422252   89.520761
# min      0.000000  1.604813e+09    1.000000  -54.800000 -175.200000
# 25%      2.000000  1.604813e+09   61.000000   -2.620000  -65.235000
# 50%     47.000000  1.604814e+09   76.000000   25.330000   20.270000
# 75%     89.000000  1.604814e+09   87.000000   46.730000   92.690000
# max    100.000000  1.604814e+09  100.000000   78.220000  178.420000
#
#          Max Temp  Wind Speed
# count  571.000000  571.000000
# mean    58.707618    8.504904
# std     22.067171    6.079043
# min    -26.630000    0.220000
# 25%     44.355000    4.305000
# 50%     63.000000    6.930000
# 75%     76.930000   11.520000
# max     96.800000   40.020000

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Plot the scattered plot between the relationships of city latitude and max tempurature
plt.scatter(city_data["Lat"], city_data["Max Temp"], edgecolor = "black", facecolor = "cornflowerblue")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature (11/07/20)")
plt.grid()
plt.savefig("output_data/City Latitude vs Max Temperature.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Plot the scattered plot between the relationships of city latitude and humidity
plt.scatter(city_data["Lat"], city_data["Humidity"], edgecolor = "black", facecolor = "cornflowerblue")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (11/07/20)")
plt.grid()
plt.savefig("output_data/City Latitude vs Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Plot the scattered plot between the relationships of city latitude and Cloudiness
plt.scatter(city_data["Lat"], city_data["Cloudiness"], edgecolor = "black", facecolor = "cornflowerblue")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (11/07/20)")
plt.grid()
plt.savefig("output_data/City Latitude vs Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Plot the scattered plot between the relationships of city latitude and wind speed
plt.scatter(city_data["Lat"], city_data["Wind Speed"], edgecolor = "black", facecolor = "cornflowerblue")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed (11/07/20)")
plt.grid()
plt.savefig("output_data/City Latitude vs Wind Speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Split the city data to Northern and Southern Hemisphere
northern = city_data[city_data["Lat"] >= 0]
southern = city_data[city_data["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Compute the regression and correlation coefficient between city latitude and max tempurature of Northern Hemisphere
regression1 = sts.linregress(northern["Lat"], northern["Max Temp"])
regression_line1 = regression1[0] * (northern["Lat"]) + regression1[1]
r_value1 = sts.pearsonr(northern["Lat"], northern["Max Temp"])[0]

# %%
# Plot the scattered plot and the regression line between city latitude and max tempurature of Northern Hemisphere
print(f"The r-value is: {r_value1}")
plt.scatter(northern["Lat"], northern["Max Temp"], edgecolor = "black", facecolor = "cornflowerblue")
plt.plot(northern["Lat"], regression_line1, color = "red")
plt.annotate("y = " + str(round(regression1[0],2)) + "x + " + str(round(regression1[1],2)), (12,20), size = 13, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature of Northern Hemisphere")
plt.savefig("output_data/City Latitude vs Max Temperature of Northern Hemisphere.png")
plt.show()
# Out:
# The r-value is: -0.876142068314379

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# compute the regression and correlation coefficient between city latitude and max tempurature of Southern Hemisphere
regression2 = sts.linregress(southern["Lat"], southern["Max Temp"])
regression_line2 = regression2[0] * (southern["Lat"]) + regression2[1]
r_value2 = sts.pearsonr(southern["Lat"], southern["Max Temp"])[0]

# %%
# plot the scattered plot and the regression line between city latitude and max tempurature of Southern Hemisphere
print(f"The r-value is: {r_value2}")
plt.scatter(southern["Lat"], southern["Max Temp"], edgecolor = "black", facecolor = "cornflowerblue")
plt.plot(southern["Lat"], regression_line2, color = "red")
plt.annotate("y = " + str(round(regression2[0],2)) + "x + " + str(round(regression2[1],2)), (-50,90), size = 13, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature of Southern Hemisphere")
plt.show()
plt.savefig("output_data/City Latitude vs Max Temperature of Southern Hemisphere.png")
# Out:
# The r-value is: 0.6557212262178516

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Compute the regression line and correlation coefficient between city latitude and humidity of Northern Hemisphere
regression3 = sts.linregress(northern["Lat"], northern["Humidity"])
regression_line3 = regression3[0] * (northern["Lat"]) + regression3[1]
r_value3 = sts.pearsonr(northern["Lat"], northern["Humidity"])[0]

# %%
# plot the scattered plot and the regression line between city latitude and humidity of Northern Hemisphere
print(f"The r-value is: {r_value3}")
plt.scatter(northern["Lat"], northern["Humidity"], edgecolor = "black", facecolor = "cornflowerblue")
plt.plot(northern["Lat"], regression_line3, color = "red")
plt.annotate("y = " + str(round(regression3[0],2)) + "x + " + str(round(regression3[1],2)), (50,20), size = 13, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity of Northern Hemisphere")
plt.show()
plt.savefig("output_data/City Latitude vs Humdidity of Northern Hemisphere.png")
# Out:
# The r-value is: 0.29351904555348796

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Compute the regression line and correlation coefficient between city latitude and humidity of Southern Hemisphere
regression4 = sts.linregress(southern["Lat"], southern["Humidity"])
regression_line4 = regression4[0] * (southern["Lat"]) + regression4[1]
r_value4 = sts.pearsonr(southern["Lat"], southern["Humidity"])[0]

# %%
# plot the scattered plot and the regression line between city latitude and humidity of Southern Hemisphere
print(f"The r-value is: {r_value4}")
plt.scatter(southern["Lat"], southern["Humidity"], edgecolor = "black", facecolor = "cornflowerblue")
plt.plot(southern["Lat"], regression_line4, color = "red")
plt.annotate("y = " + str(round(regression4[0],2)) + "x + " + str(round(regression4[1],2)), (-20,20), size = 13, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity of Southern Hemisphere")
plt.show()
plt.savefig("output_data/City Latitude vs Humidity of Southern Hemisphere.png")
# Out:
# The r-value is: 0.2650267862772795

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Compute the regression line and correlation coefficient between city latitude and cloudiness of Northern Hemisphere
regression5 = sts.linregress(northern["Lat"], northern["Cloudiness"])
regression_line5 = regression5[0] * (northern["Lat"]) + regression5[1]
r_value5 = sts.pearsonr(northern["Lat"], northern["Cloudiness"])[0]

# %%
# plot the scattered plot and the regression line between city latitude and cloudiness of Northern Hemisphere
print(f"The r-value is: {r_value5}")
plt.scatter(northern["Lat"], northern["Cloudiness"], edgecolor = "black", facecolor = "cornflowerblue")
plt.plot(northern["Lat"], regression_line5, color = "red")
plt.annotate("y = " + str(round(regression5[0],2)) + "x + " + str(round(regression5[1],2)), (20,60), size = 13, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness of Northern Hemisphere")
plt.show()
plt.savefig("output_data/City Latitude vs Cloudiness of Northern Hemisphere.png")
# Out:
# The r-value is: 0.28294435766135667

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Compute the regression line and correlation coefficient between city latitude and cloudiness of Southern Hemisphere
regression6 = sts.linregress(southern["Lat"], southern["Cloudiness"])
regression_line6 = regression6[0] * (southern["Lat"]) + regression6[1]
r_value6 = sts.pearsonr(southern["Lat"], southern["Cloudiness"])[0]

# %%
# plot the scattered plot and the regression line between city latitude and cloudiness of Southern Hemisphere
print(f"The r-value is: {r_value6}")
plt.scatter(southern["Lat"], southern["Cloudiness"], edgecolor = "black", facecolor = "cornflowerblue")
plt.plot(southern["Lat"], regression_line6, color = "red")
plt.annotate("y = " + str(round(regression6[0],2)) + "x + " + str(round(regression6[1],2)), (-55,65), size = 13, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness of Southern Hemisphere")
plt.show()
plt.savefig("output_data/City Latitude vs Cloudiness of Southern Hemisphere.png")
# Out:
# The r-value is: 0.4280291969229101

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Compute the regression line and correlation coefficient between city latitude and wind speed of Northern Hemisphere
regression7 = sts.linregress(northern["Lat"], northern["Wind Speed"])
regression_line7 = regression7[0] * (northern["Lat"]) + regression7[1]
r_value7 = sts.pearsonr(northern["Lat"], northern["Wind Speed"])[0]

# %%
# plot the scattered plot and the regression line between city latitude and wind speed of Northern Hemisphere
print(f"The r-value is: {r_value7}")
plt.scatter(northern["Lat"], northern["Wind Speed"], edgecolor = "black", facecolor = "cornflowerblue")
plt.plot(northern["Lat"], regression_line7, color = "red")
plt.annotate("y = " + str(round(regression7[0],2)) + "x + " + str(round(regression7[1],2)), (20,40), size = 13, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed of Northern Hemisphere")
plt.show()
plt.savefig("output_data/City Latitude vs Wind Speed of Northern Hemisphere.png")
# Out:
# The r-value is: 0.22165739059725675

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Compute the regression line and correlation coefficient between city latitude and wind speed of southern Hemisphere
regression8 = sts.linregress(southern["Lat"], southern["Wind Speed"])
regression_line8 = regression8[0] * (southern["Lat"]) + regression8[1]
r_value8 = sts.pearsonr(southern["Lat"], southern["Wind Speed"])[0]

# %%
# plot the scattered plot and the regression line between city latitude and wind speed of Southern Hemisphere
print(f"The r-value is: {r_value8}")
plt.scatter(southern["Lat"], southern["Wind Speed"], edgecolor = "black", facecolor = "cornflowerblue")
plt.plot(southern["Lat"], regression_line8, color = "red")
plt.annotate("y = " + str(round(regression8[0],2)) + "x + " + str(round(regression8[1],2)), (-20,20), size = 13, color = "red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed of Southern Hemisphere")
plt.show()
plt.savefig("output_data/City Latitude vs Wind Speed of Southern Hemisphere.png")
# Out:
# The r-value is: -0.3571321897090898
